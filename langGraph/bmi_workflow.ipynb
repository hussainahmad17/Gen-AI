# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
# define the state

class BMIState(TypedDict):
    weight: float
    height: float
    bmi: float
    category: str


def calculate_bmi(state: BMIState) -> BMIState:
    weight = state["weight"] 
    height = state["height"]
    bmi = weight/(height**2)
    state["bmi"] = round(bmi, 2)


    return state


def label_bmi(state: BMIState) -> BMIState:
    bmi = state["bmi"]
    if bmi < 18.5:
        state["category"] = "Underweight"
    elif 18.5 <= bmi < 24.9:
        state["category"] = "Normal weight"
    elif 25 <= bmi < 29.9:
        state["category"] = "Overweight"
    else:
        state["category"] = "Obesity"

    return state


# define the Graph and pass the state to it
graph = StateGraph(BMIState)


# add nodes to the graph
graph.add_node("calculate_bmi", calculate_bmi)
graph.add_node("label_bmi", label_bmi)


# add edges to the graph
graph.add_edge(START, "calculate_bmi")
graph.add_edge("calculate_bmi", "label_bmi")
graph.add_edge("label_bmi", END)

# Compile the graph
workflow = graph.compile()

# %%
# execute the graph with some initial state
output_state = workflow.invoke({"weight": 70, "height": 1.75})
print(output_state)  # Output: {'weight': 70, 'height': 1.75, 'bmi': 22.86}
# Out:
# {'weight': 70, 'height': 1.75, 'bmi': 22.86, 'category': 'Normalsfsfsfsfweight'}
